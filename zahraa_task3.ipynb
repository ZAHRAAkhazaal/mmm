# %% [markdown]
# <a href="https://colab.research.google.com/github/ZAHRAAkhazaal/mmm/blob/main/zahraa_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09c5c537-b299-443a-8cd5-06f58824a836" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09c5c537-b299-443a-8cd5-06f58824a836">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving top50.csv to top50.csv

# %%
import pandas as pd

# %%
data=pd.read_csv('top50.csv',encoding='ISO-8859-1')

# %%
data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %% [markdown]
# ### **Check if have null value**  :-we see  that no null value

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Track.Name          0
# Artist.Name         0
# Genre               0
# Beats.Per.Minute    0
# Energy              0
# Danceability        0
# Loudness..dB..      0
# Liveness            0
# Valence.            0
# Length.             0
# Acousticness..      0
# Speechiness.        0
# Popularity          0
# dtype: int64

# %% [markdown]
# # **Remove first Columns** because its unuseful

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %% [markdown]
# # Rename the columns to simplify deal with it in future

# %%
data.rename(columns={'Track.Name':'Track Name',
                'Artist.Name':'Artist Name',
                'Beats.Per.Minute':'Beats Per Minute',
                'Loudness..dB..':'Loudness in dB',
                'Valence.':'Valence',
                'Length.':'Length',
                'Acousticness..':'Acousticness',
                'Speechiness.':'Speechiness' } ,inplace =True)

# %% [markdown]
# **Display the information of dataset to determine type of each columns**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        50 non-null     object
#  1   Artist Name       50 non-null     object
#  2   Genre             50 non-null     object
#  3   Beats Per Minute  50 non-null     int64
#  4   Energy            50 non-null     int64
#  5   Danceability      50 non-null     int64
#  6   Loudness in dB    50 non-null     int64
#  7   Liveness          50 non-null     int64
#  8   Valence           50 non-null     int64
#  9   Length            50 non-null     int64
#  10  Acousticness      50 non-null     int64
#  11  Speechiness       50 non-null     int64
#  12  Popularity        50 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 5.2+ KB

# %% [markdown]
# Count the value of each elelment in columns Genre

# %%
data.Genre.value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: Genre, dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
 plt.figure(figsize=(10,10))
sns.countplot(y='Genre',data=data)

# %% [markdown]
# Plot heatmap to describe the relationship between each column to show negative and positive relatioship
# from heatmap we see negative realtionship between ,(Beat per minute and speechness),(Dancebility and liveness),(Acousticness and Length)

# %%
plt.Figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True,fmt = '.1f',cbar=True)

# %% [markdown]
# Bar plot   between Artist name and Popularity to detemine the most popular song

# %%
 plt.figure(figsize=(10,10))
sns.barplot(x='Popularity',y='Track Name',data=data,label=True)
plt.ylabel='Track Name'
plt.xlabel='Popularity'
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# Histogram plot for ccolumn Beat Per Minute

# %%
sns.histplot(x=data['Beats Per Minute'],data=data)

# %%
sns.histplot(x='Energy',data=data)

# %%
sns.histplot(x='Danceability',data=data)

# %%
sns.histplot(x='Loudness in dB',data=data)

# %%
sns.histplot(x='Liveness',data=data)

# %%
sns.histplot(x='Valence',data=data)

# %%
sns.histplot(x='Acousticness',data=data)

# %% [markdown]
# **Not that when Popularity increase the liveness decrease**
# we see that the relationship is almost positive

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Liveness',y='Popularity',data=data)

# %% [markdown]
# we see that relationship between speechness and Beat is negative

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Speechiness',y='Beats Per Minute',data=data)

# %% [markdown]
# we see the relation between loudness and engergy is linear poistive but in heatmap appear is .7 because the loudness in dB is neagive sign

# %%
sns.scatterplot(x='Loudness in dB',y='Energy',data=data)

# %% [markdown]
# Negtive relation between liveness and danceability

# %%
sns.scatterplot(x='Danceability',y='Liveness',data=data)

# %% [markdown]
# Almost negative Relation between Length and Acousticness

# %%
plt.figure(figsize = (10,10))
sns.lineplot(x='Acousticness',y='Length',data=data)

# %% [markdown]
# Pie plot

# %%
plt.figure(figsize = (10,10))
pie = data.Genre.value_counts()
labels = pie.index
sizes = pie.values
plt.pie(sizes, labels=labels,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb43ab6e550>,
# ...
#  [Text(0.9639373540021144, 0.5299290306818474, 'dance pop'),
#   Text(0.13786657939974728, 1.0913261686061657, 'pop'),
#   Text(-0.6465637650236903, 0.8899187028927927, 'latin'),
#   Text(-0.9953097513542601, 0.46835723423378556, 'canadian hip hop'),
#   Text(-1.09782939975141, 0.06906959563700359, 'edm'),
#   Text(-1.0654414851813474, -0.2735588449576527, 'reggaeton'),
#   Text(-0.9639373664059986, -0.529929008119265, 'reggaeton flow'),
#   Text(-0.8018655204790328, -0.7530017842388489, 'panamanian pop'),
#   Text(-0.5894095170857548, -0.9287606910118115, 'canadian pop'),
#   Text(-0.3399187476842657, -1.0461621504206509, 'electropop'),
#   Text(-0.06906963418183067, -1.0978293973263735, 'country rap'),
#   Text(0.206119378263608, -1.0805159887314135, 'dfw rap'),
#   Text(0.46835715269461237, -0.9953097897236798, 'brostep'),
#   Text(0.6465637129485624, -0.8899187407275843, 'trap music'),
# ...

# %%
plt.Figure(figsize=(20,20))
sns.swarmplot(x='Popularity',y='Liveness',hue='Genre',data=data)

# %% [markdown]
# we see in the highest popularity in 95 have low speechness less than 40 but in populity 85 have the hightest speechness

# %%
plt.Figure(figsize=(20,20))
sns.barplot(x='Popularity',y='Speechiness',data=data)
